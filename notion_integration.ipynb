# %% [markdown]
# # Import Packages

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import requests
import json
from dotenv import load_dotenv
import os
from google.cloud import bigquery, bigquery_storage
from joblib import Parallel, delayed
from ratelimiter import RateLimiter
import warnings
warnings.filterwarnings("ignore")

# Load environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# # Define Your Inputs

# %%
# Define the start date in the format "YYYY-MM-DD"
START_DATE = "2023-01-01"

# Define the end date in the format "YYYY-MM-DD"
END_DATE = "2024-09-30"

# If this is set to True, the script will add data from the last crawler run ONLY
# If it is set to False, the script will pull data from the start date to the end date.
IS_PULL_DATA_FROM_LAST_CRAWLER_RUN = False

# Define the max number of requests per minute
MAX_REQUESTS_PER_MINUTE = 170

# %% [markdown]
# # Define Global Non-User Defined Inputs

# %%
# Define the maximum tries for the backoff decorator
EXP_BACKOFF_MAX_TRIES = 10

# Define the relevant columns to be extracted from the downloaded data
RELEVANT_COLS = [
    "job_title_name", "posted_on", "company_name", "remote", "city", "plz", "salary_low",
    "salary_high", "salary_type", "job_type", "phone_number", "industry", "job_description", "crawled_timestamp", "job_source"
]

# Define the numeric columns
NUMERIC_COLS = ["plz", "salary_low", "salary_high"]

# Retrieve the Notion API token
NOTION_API_TOKEN = os.getenv("NOTION_API_TOKEN")

# Retrieve the database ID
DATABASE_ID = os.getenv("DATABASE_ID")

# Define the request headers including Authorization token
headers = {
    "Authorization": f"Bearer {NOTION_API_TOKEN}",
    "Content-Type": "application/json",
    "Notion-Version": "2022-06-28"
}

# %% [markdown]
# # Instantiate the BQ clients

# %%
bq_client = bigquery.Client(project="web-scraping-371310")
bq_storage_client = bigquery_storage.BigQueryReadClient()

# %% [markdown]
# # Define the Query

# %%
# Define the time period filter
if IS_PULL_DATA_FROM_LAST_CRAWLER_RUN:
    TIME_PERIOD_FILTER = "WHERE crawled_timestamp = (SELECT MAX(crawled_timestamp) FROM `web-scraping-371310.crawled_datasets.laura_indeed_data`)"
else:
    TIME_PERIOD_FILTER = f"WHERE crawled_timestamp BETWEEN TIMESTAMP('{START_DATE}') AND TIMESTAMP('{END_DATE}')"

# Create the query
raw_data_query = f"""
SELECT *
FROM `web-scraping-371310.crawled_datasets.laura_indeed_data`
{TIME_PERIOD_FILTER}
QUALIFY ROW_NUMBER() OVER (PARTITION BY job_title_name, company_name, city order by crawled_timestamp asc) = 1
"""

# Execute the query
df_indeed_data = pd.DataFrame(bq_client.query(raw_data_query).result().to_dataframe(bqstorage_client=bq_storage_client))

# Display the data frame
df_indeed_data
# Out:
#                                          job_title_name  \
# 0     PhD Researcher (f/m/x) - Electrochemical conve...
# 1     Senior / Principal Water Treatment Consultant ...
# 2              Werkstudent*in Energiemanagement (m/w/d)
# 3     Business Manager - Strategic Sustainability Co...
# 4       Project Manager- Automotive & Mobility Projects
# ...                                                 ...
# 5495              Sales Manager (M/W/D), Teil-/Vollzeit
# 5496   Kaufmännische Sachbearbeiter (m/w/d) Back Office
# 5497                  Senior Frontend Developer (m/w/d)
# 5498  Senior Piping Engineer (m/w/d) Rohrleitungstec...
# 5499                 Trainee Finance & Treasury (m/w/d)
#
#                               job_type shift_and_schedule  \
# 0
# 1                       Festanstellung
# 2     Werkstudent, Befristeter Vertrag
# 3                       Festanstellung
# 4
# ...                                ...                ...
# 5495
# 5496
# 5497
# 5498                    Festanstellung
# 5499
#
#                                    company_name  \
# 0     Helmholtz-Zentrum für Umweltforschung UFZ
# 1                                       Ramboll
# 2             Zentrum für Sonnenenergie- und...
# 3                                       Ramboll
# 4                                      SYSTEMIQ
# ...                                         ...
# 5495                         SVP Deutschland AG
# 5496                   DERICHEBOURG Umwelt GmbH
# 5497             Mineral Minds Deutschland GmbH
# 5498            Hitachi Zosen Inova Steinmüller
# 5499      Papierfabrik Adolf Jass GmbH & Co. KG
#
#                                      company_indeed_url                  city  \
# 0     https://de.indeed.com/cmp/Helmholtz--zentrum-F...               Leipzig
# 1     https://de.indeed.com/cmp/Ramboll?campaignid=m...            Düsseldorf
# 2     https://de.indeed.com/cmp/Zentrum-F%C3%BCr-Son...             Stuttgart
# 3     https://de.indeed.com/cmp/Ramboll?campaignid=m...               Hamburg
# 4     https://de.indeed.com/cmp/Systemiq?campaignid=...               München
# ...                                                 ...                   ...
# 5495  https://de.indeed.com/cmp/Svp-825cc399?campaig...  Hybrides Arbeiten in
# 5496  https://de.indeed.com/cmp/Derichebourg?campaig...            Weischlitz
# 5497  https://de.indeed.com/cmp/Mineral-Minds-Deutsc...  Hybrides Arbeiten in
# 5498  https://de.indeed.com/cmp/Hitachi-Zosen-Inova-...           Gummersbach
# 5499  https://de.indeed.com/cmp/Papierfabrik-Adolf-J...                 Fulda
#
#                       remote salary  crawled_page_rank  \
# 0                       None   None                 32
# 1     Zum Teil im Homeoffice   None                  5
# 2                       None   None                 31
# 3     Zum Teil im Homeoffice   None                 31
# 4                       None   None                 32
# ...                      ...    ...                ...
# 5495                    None   None                 63
# 5496                    None   None                 63
# 5497                    None   None                 63
# 5498                    None   None                 63
# 5499                    None   None                 63
#
#                                            job_page_url  \
# 0     https://de.indeed.com/rc/clk?jk=e23711ee9c3ad7...
# 1     https://de.indeed.com/rc/clk?jk=f619ab1748c968...
# 2     https://de.indeed.com/rc/clk?jk=f30394b1cb3559...
# 3     https://de.indeed.com/rc/clk?jk=4d9dd5fb66a864...
# 4     https://de.indeed.com/rc/clk?jk=15236c702bc05e...
# ...                                                 ...
# 5495  https://de.indeed.com/rc/clk?jk=e666da1f7d0844...
# 5496  https://de.indeed.com/rc/clk?jk=6b69552f2c14ec...
# 5497  https://de.indeed.com/rc/clk?jk=2d42782b65f927...
# 5498  https://de.indeed.com/rc/clk?jk=985644f23e12dc...
# 5499  https://de.indeed.com/rc/clk?jk=6e7cdeab679597...
#
#                       posted_on  \
# 0       Vor 13 Tagen geschaltet
# 1        Vor 5 Tagen geschaltet
# 2     Vor > 30 Tagen geschaltet
# 3     Vor > 30 Tagen geschaltet
# 4     Vor > 30 Tagen geschaltet
# ...                         ...
# 5495         Aktiv: vor 2 Tagen
# 5496        Aktiv: vor 23 Tagen
# 5497         Aktiv: vor 8 Tagen
# 5498  Vor > 30 Tagen geschaltet
# 5499  Vor > 30 Tagen geschaltet
#
#                                        listing_page_url  \
# 0     https://de.indeed.com/jobs?q=Circular%20Econom...
# 1     https://de.indeed.com/jobs?q=Circularity&l=Deu...
# 2     https://de.indeed.com/jobs?q=Circular%20Econom...
# 3     https://de.indeed.com/jobs?q=Circular%20Econom...
# 4     https://de.indeed.com/jobs?q=Circular%20Econom...
# ...                                                 ...
# 5495  https://de.indeed.com/jobs?q=Kreislaufwirtscha...
# 5496  https://de.indeed.com/jobs?q=Kreislaufwirtscha...
# 5497  https://de.indeed.com/jobs?q=Kreislaufwirtscha...
# 5498  https://de.indeed.com/jobs?q=Kreislaufwirtscha...
# 5499  https://de.indeed.com/jobs?q=Kreislaufwirtscha...
#
#                                         job_description  \
# 0     Place of work\nLeipzig\nWorking time\n65 % (25...
# 1     Job Description\nAny Ramboll Germany Office\nA...
# 2     // Zentrum für Sonnenenergie- und Wasserstoff-...
# 3     Job Description\nMünchen, Hamburg, Berlin, Fra...
# 4     Systemiq, the\nsystems change company\nand cer...
# ...                                                 ...
# 5495  Wir suchen zum nächstmöglichen Zeitpunkt eine/...
# 5496  Für unsere Niederlassung in Weischlitz-Reuth s...
# 5497  Für unser Entwicklungsteam suchen wir zum näch...
# 5498  Unternehmensbeschreibung\nAls Tochtergesellsch...
# 5499  Jass ist familiengeführt, partnerschaftlich, n...
#
#              crawled_timestamp crawler_name domain salary_type  salary_low  \
# 0    2023-12-19 09:46:15+00:00    crawler_1     de        None         NaN
# 1    2024-03-13 03:02:26+00:00    crawler_2     de        None         NaN
# 2    2024-03-13 03:09:38+00:00    crawler_1     de        None         NaN
# 3    2024-02-18 07:57:34+00:00    crawler_1     de        None         NaN
# 4    2023-12-19 09:46:19+00:00    crawler_1     de        None         NaN
# ...                        ...          ...    ...         ...         ...
# 5495 2024-05-15 09:02:02+00:00    crawler_3     de        None         NaN
# 5496 2024-09-04 09:10:35+00:00    crawler_3     de        None         NaN
# 5497 2024-05-08 09:03:29+00:00    crawler_3     de        None         NaN
# 5498 2024-04-10 03:05:03+00:00    crawler_3     de        None         NaN
# 5499 2024-06-26 09:03:28+00:00    crawler_3     de        None         NaN
#
#       salary_high    plz search_query phone_number industry  \
# 0             NaN   None         None         None     None
# 1             NaN  40476         None         None     None
# 2             NaN  70563         None         None     None
# 3             NaN  22763         None         None     None
# 4             NaN   None         None         None     None
# ...           ...    ...          ...          ...      ...
# 5495          NaN  69115         None         None     None
# 5496          NaN  08538         None         None     None
# 5497          NaN  70376         None         None     None
# 5498          NaN  51643         None         None     None
# 5499          NaN  36039         None         None     None
#
#      industry_match_type  industry_match_idx
# 0               no_match               11772
# 1               no_match               11772
# 2               no_match               11772
# 3               no_match               11772
# 4               no_match               11772
# ...                  ...                 ...
# 5495            no_match               11772
# 5496            no_match               11772
# 5497            no_match               11772
# 5498            no_match               11772
# 5499            no_match               11772
#
# [5500 rows x 25 columns]

# %% [markdown]
# # Clean the data

# %%
# Add a new column called job_source
df_indeed_data.loc[:, "job_source"] = "Indeed Crawler"

# Add a new column called unique_identifier
df_indeed_data.loc[:, "unique_identifier"] = df_indeed_data["job_title_name"] + df_indeed_data["company_name"] + df_indeed_data["city"] + df_indeed_data["crawled_timestamp"].astype(str)

# Choose the relevant columns from the data frame
df_indeed_data = df_indeed_data[RELEVANT_COLS]

# Change the data types of numeric fields
for num_col in NUMERIC_COLS:
    df_indeed_data[num_col] = pd.to_numeric(df_indeed_data[num_col])

# Iterate over each string column and override None values with empty strings
for col in list(df_indeed_data.select_dtypes(include="object").columns):
    df_indeed_data[col].fillna("", inplace=True)

for col in list(df_indeed_data.select_dtypes(include="float64").columns):
    df_indeed_data[col].fillna(0, inplace=True)

# Display the data frame
df_indeed_data
# Out:
#                                          job_title_name  \
# 0     PhD Researcher (f/m/x) - Electrochemical conve...
# 1     Senior / Principal Water Treatment Consultant ...
# 2              Werkstudent*in Energiemanagement (m/w/d)
# 3     Business Manager - Strategic Sustainability Co...
# 4       Project Manager- Automotive & Mobility Projects
# ...                                                 ...
# 5495              Sales Manager (M/W/D), Teil-/Vollzeit
# 5496   Kaufmännische Sachbearbeiter (m/w/d) Back Office
# 5497                  Senior Frontend Developer (m/w/d)
# 5498  Senior Piping Engineer (m/w/d) Rohrleitungstec...
# 5499                 Trainee Finance & Treasury (m/w/d)
#
#                       posted_on                               company_name  \
# 0       Vor 13 Tagen geschaltet  Helmholtz-Zentrum für Umweltforschung UFZ
# 1        Vor 5 Tagen geschaltet                                    Ramboll
# 2     Vor > 30 Tagen geschaltet          Zentrum für Sonnenenergie- und...
# 3     Vor > 30 Tagen geschaltet                                    Ramboll
# 4     Vor > 30 Tagen geschaltet                                   SYSTEMIQ
# ...                         ...                                        ...
# 5495         Aktiv: vor 2 Tagen                         SVP Deutschland AG
# 5496        Aktiv: vor 23 Tagen                   DERICHEBOURG Umwelt GmbH
# 5497         Aktiv: vor 8 Tagen             Mineral Minds Deutschland GmbH
# 5498  Vor > 30 Tagen geschaltet            Hitachi Zosen Inova Steinmüller
# 5499  Vor > 30 Tagen geschaltet      Papierfabrik Adolf Jass GmbH & Co. KG
#
#                       remote                  city      plz  salary_low  \
# 0                                          Leipzig      0.0         0.0
# 1     Zum Teil im Homeoffice            Düsseldorf  40476.0         0.0
# 2                                        Stuttgart  70563.0         0.0
# 3     Zum Teil im Homeoffice               Hamburg  22763.0         0.0
# 4                                          München      0.0         0.0
# ...                      ...                   ...      ...         ...
# 5495                          Hybrides Arbeiten in  69115.0         0.0
# 5496                                    Weischlitz   8538.0         0.0
# 5497                          Hybrides Arbeiten in  70376.0         0.0
# 5498                                   Gummersbach  51643.0         0.0
# 5499                                         Fulda  36039.0         0.0
#
#       salary_high salary_type                          job_type phone_number  \
# 0             0.0
# 1             0.0                                Festanstellung
# 2             0.0              Werkstudent, Befristeter Vertrag
# 3             0.0                                Festanstellung
# 4             0.0
# ...           ...         ...                               ...          ...
# 5495          0.0
# 5496          0.0
# 5497          0.0
# 5498          0.0                                Festanstellung
# 5499          0.0
#
#      industry                                    job_description  \
# 0              Place of work\nLeipzig\nWorking time\n65 % (25...
# 1              Job Description\nAny Ramboll Germany Office\nA...
# 2              // Zentrum für Sonnenenergie- und Wasserstoff-...
# 3              Job Description\nMünchen, Hamburg, Berlin, Fra...
# 4              Systemiq, the\nsystems change company\nand cer...
# ...       ...                                                ...
# 5495           Wir suchen zum nächstmöglichen Zeitpunkt eine/...
# 5496           Für unsere Niederlassung in Weischlitz-Reuth s...
# 5497           Für unser Entwicklungsteam suchen wir zum näch...
# 5498           Unternehmensbeschreibung\nAls Tochtergesellsch...
# 5499           Jass ist familiengeführt, partnerschaftlich, n...
#
#              crawled_timestamp      job_source
# 0    2023-12-19 09:46:15+00:00  Indeed Crawler
# 1    2024-03-13 03:02:26+00:00  Indeed Crawler
# 2    2024-03-13 03:09:38+00:00  Indeed Crawler
# 3    2024-02-18 07:57:34+00:00  Indeed Crawler
# 4    2023-12-19 09:46:19+00:00  Indeed Crawler
# ...                        ...             ...
# 5495 2024-05-15 09:02:02+00:00  Indeed Crawler
# 5496 2024-09-04 09:10:35+00:00  Indeed Crawler
# 5497 2024-05-08 09:03:29+00:00  Indeed Crawler
# 5498 2024-04-10 03:05:03+00:00  Indeed Crawler
# 5499 2024-06-26 09:03:28+00:00  Indeed Crawler
#
# [5500 rows x 15 columns]

# %% [markdown]
# # Create a function to return the text content of a field in the database

# %%
def generate_text_dict(row, col):
    """
    This function generates a dictionary with the rich text format for a given column in a row.
    """
    return {
        "rich_text": [
            {
                "text": {
                    "content": row[col]
                }
            }
        ]
    }

def generate_numeric_dict(row, col):
    """
    This function generates a dictionary with the number format for a given column in a row.
    """
    return {
        "number": row[col]
    }

# %% [markdown]
# # Define a function to upload data to the Notion database

# %%
@RateLimiter(max_calls=MAX_REQUESTS_PER_MINUTE, period=60)
def upload_row_to_notion_db(row, counter):
    """
    A function to upload a row to the Notion database
    """
    # Increment the counter so the first record is 1
    counter += 1

    # Data for the new page (record) in the database
    data = {
        "parent": {
            "database_id": DATABASE_ID
        },
        "properties": {
            # job_title_name field
            "job_title_name": {
                "title": [
                    {
                        "text": {
                            "content": row["job_title_name"]
                        }
                    }
                ]
            },

            # posted_on field
            "posted_on": generate_text_dict(row=row, col="posted_on"),
            
            # company_name field
            "company_name": generate_text_dict(row=row, col="company_name"),
            
            # remote field
            "remote": generate_text_dict(row=row, col="remote"),
            
            # city field
            "city": generate_text_dict(row=row, col="city"),
            
            # plz field
            "plz": generate_numeric_dict(row=row, col="plz"),

            # salary_low field
            "salary_low": generate_numeric_dict(row=row, col="salary_low"),

            # salary_high field
            "salary_high": generate_numeric_dict(row=row, col="salary_high"),
            
            # salary_type field
            "salary_type": generate_text_dict(row=row, col="salary_type"),

            # job_type field
            "job_type": generate_text_dict(row=row, col="job_type"),

            # phone_number field
            "phone_number": generate_text_dict(row=row, col="phone_number"),

            # industry field
            "industry": generate_text_dict(row=row, col="industry"),
            
            # job_description field
            "job_description": generate_text_dict(row=row, col="job_description"),

            # crawled_timestamp field
            "crawled_timestamp": {
                "date": {
                    "start": row["crawled_timestamp"].strftime("%Y-%m-%d %H:%M:%S")
                }
            },

            # job_source field
            "job_source": {
                "select": {
                    "name": row["job_source"]
                }
            }
        }
    }

    # Make a request to the Notion API
    response = requests.post('https://api.notion.com/v1/pages', headers=headers, data=json.dumps(data))

    # Check if the request was successful
    if response.status_code == 200:
        print(f"The job title -> {row['job_title_name']} was added successfully. This is record {counter} out of {len(df_indeed_data)}!")
    else:
        print(f"Failed to add record number {counter} with job title -> {row['job_title_name']}: ", response.status_code, response.text)

# %%
# Export to CSV
df_indeed_data.to_csv("indeed_data_since_the_beginning_deduplicated.csv", index=False)

# %% [markdown]
# # Upload the records to the Notion database

# %%
parallel_job = Parallel(n_jobs=-1, backend="threading")(
    delayed(upload_row_to_notion_db)(row, counter) for counter, row in df_indeed_data.iterrows()
)
# Out:
# The job title -> Studentische Mitarbeiterin/ Studentischer Mitarbeiter (w/m/d) | BDI-Initiative Circular Economy was added successfully. This is record 181 out of 5500!
